# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

driver = webdriver.Chrome(service=Service("../driver/chromedriver"))
driver.get("https://www.selenium.dev/")

driver.current_url
# Out:
# 'https://www.selenium.dev/'

# %%
from selenium.webdriver.common.by import By

driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

driver.execute_script("window.scrollTo(0, 0)")

element = driver.find_element(By.CLASS_NAME,"d-flex.justify-content-center.p-5.td-box--100")
child = element.find_element(By.CLASS_NAME, "selenium")

print(child.text)

driver.execute_script("arguments[0].scrollIntoView(false);", child)

driver.save_screenshot("../data/image_01.png")
# Out:
# News
# True

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

image = mpimg.imread("../data/image_01.png")
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
search_btn = driver.find_element(By.XPATH,"""//*[@id="main_navbar"]/ul/li[3]/a/span""")
search_btn.click()

# %%
search_btn = driver.find_element(By.XPATH,"""//*[@id="docsearch-1"]/button""")
search_btn.click()

# %%
from selenium.webdriver.common.keys import Keys

search_doc = driver.find_element(By.CSS_SELECTOR,"#docsearch-input")
search_doc.send_keys('find elements')
search_doc.send_keys(Keys.ENTER)

# %%
python_panel = driver.find_element(By.ID,"tabs-10-02")
python_code = python_panel.find_element(By.TAG_NAME,"code")

print(python_code.text)
driver.back()
# Out:
# from selenium import webdriver
# from selenium.webdriver.common.by import By
#
# driver = webdriver.Chrome()
# driver.get("https://www.example.com")
# ##get elements from parent element using TAG_NAME
#
#     # Get element with tag name 'div'
# element = driver.find_element(By.TAG_NAME, 'div')
#
#     # Get all the elements available with tag name 'p'
# elements = element.find_elements(By.TAG_NAME, 'p')
# for e in elements:
#     print(e.text)
#
# ##get elements from parent element using XPATH
# ##NOTE: in order to utilize XPATH from current element, you must add "." to beginning of path
#
#     # Get first element of tag 'ul'
# element = driver.find_element(By.XPATH, '//ul')
#
#     # get children of tag 'ul' with tag 'li'
# elements  = driver.find_elements(By.XPATH, './/li')
# for e in elements:
#     print(e.text)

# %%
menu = driver.find_element(By.ID, "main_navbar")
li_list = menu.find_elements(By.TAG_NAME, "li")
for idx, li in enumerate(li_list):
    print("[" + str(idx) + "] ========== " )
    print(li.get_attribute("innerHTML"))
# Out:
# [0] ==========
# <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">About</a><div class="dropdown-menu" aria-labelledby="navbarDropdown"><a class="dropdown-item" href="/about">About Selenium</a>
# <a class="dropdown-item" href="/project">Structure and Governance</a>
# <a class="dropdown-item" href="/events">Events</a>
# <a class="dropdown-item" href="/ecosystem">Ecosystem</a>
# <a class="dropdown-item" href="/history">History</a>
# <a class="dropdown-item" href="/getinvolved">Get Involved</a>
# <a class="dropdown-item" href="/sponsors">Sponsors</a>
# <a class="dropdown-item" href="/sponsor">Sponsor Us</a></div>
# [1] ==========
# <a class="nav-link" href="/downloads"><span>Downloads</span></a>
# [2] ==========
# <a class="nav-link" href="/documentation"><span>Documentation</span></a>
# [3] ==========
# <a class="nav-link" href="/projects"><span>Projects</span></a>
# [4] ==========
# <a class="nav-link" href="/support"><span>Support</span></a>
# [5] ==========
# <a class="nav-link" href="/blog"><span>Blog</span></a>
# [6] ==========
# <div class="dropdown"><a class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">English</a><ul class="dropdown-menu"><li><a class="dropdown-item" href="/pt-br/">Português (Brasileiro)</a></li><li><a class="dropdown-item" href="/zh-cn/">中文简体</a></li><li><a class="dropdown-item" href="/ja/">日本語</a></li><li><a class="dropdown-item" href="/other/">Other</a></li></ul></div>
# [7] ==========
# <a class="dropdown-item" href="/pt-br/">Português (Brasileiro)</a>
# [8] ==========
# <a class="dropdown-item" href="/zh-cn/">中文简体</a>
# [9] ==========
# <a class="dropdown-item" href="/ja/">日本語</a>
# [10] ==========
# <a class="dropdown-item" href="/other/">Other</a>

# %%
about = li_list[0]
about.click()
link_list = about.find_elements(By.CLASS_NAME, "dropdown-item")
for link in link_list:
    print(link.text)

history = about.find_element(By.LINK_TEXT, "History")
# print(history.text)
# history.click()
# Out:
# About Selenium
# Structure and Governance
# Events
# Ecosystem
# History
# Get Involved
# Sponsors
# Sponsor Us

# %%
from selenium.webdriver import ActionChains
import time

actions = ActionChains(driver)
actions.click(about)
actions.click(history)
actions.perform
# Out:
# <bound method ActionChains.perform of <selenium.webdriver.common.action_chains.ActionChains object at 0x786a8b28a690>>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

driver = webdriver.Chrome(service=Service("../driver/chromedriver"))
driver.get("https://www.opinet.co.kr/searRgSelect.do")

# %%
from selenium.webdriver.common.by import By

sido = driver.find_element(By.ID, "SIDO_NM0")
sido_list = sido.find_elements(By.TAG_NAME, "option")
for idx, sido_name in enumerate(sido_list):
    print(str(idx) + ". " + sido_name.get_attribute("value"))
# Out:
# 0.
# 1. 서울특별시
# 2. 부산광역시
# 3. 대구광역시
# 4. 인천광역시
# 5. 광주광역시
# 6. 대전광역시
# 7. 울산광역시
# 8. 세종특별자치시
# 9. 경기도
# 10. 강원특별자치도
# 11. 충청북도
# 12. 충청남도
# 13. 전북특별자치도
# 14. 전라남도
# 15. 경상북도
# 16. 경상남도
# 17. 제주특별자치도

# %%
sido_names = [sido_name.get_attribute("value") for sido_name in sido_list]
sido_names = sido_names[1:]

print(sido_names[0])
sido.send_keys(sido_names[0])
# Out:
# 서울특별시

# %%
gu = driver.find_element(By.ID, "SIGUNGU_NM0")
gu_list = gu.find_elements(By.TAG_NAME, "option")

gu_names = [gu_name.get_attribute("value") for gu_name in gu_list]
print(len(gu_names), gu_names)

gu_names.remove('')
print(len(gu_names), gu_names)

gu.send_keys(gu_names[5])
# Out:
# 26 ['', '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
# 25 ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']

# %%
import time
from tqdm.notebook import tqdm

for gu_name in tqdm(gu_names[:3]):
    gu = driver.find_element(By.ID, "SIGUNGU_NM0")
    gu.send_keys(gu_name)
    driver.implicitly_wait(3)
    driver.refresh
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
driver.find_element(By.XPATH, """//*[@id="templ_list0"]/div[7]/div/a""").click()
# driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

options = webdriver.ChromeOptions()
prefs = {'download.default_directory':'/home/taemin/dev_ws/EDA/data/fuel3',
         'download.prompt_for_download':False}
options.add_experimental_option('prefs', prefs)

url = "https://www.opinet.co.kr/searRgSelect.do"
driver = webdriver.Chrome(service=Service("../driver/chromedriver"),
                          options=options)

driver.get(url)

# %%
driver.quit()

# %%
for gu_name in tqdm(gu_names):
    gu = driver.find_element(By.ID, "SIGUNGU_NM0")
    gu.send_keys(gu_name)
    driver.implicitly_wait(3)
    driver.refresh()

    driver.find_element(By.XPATH, """//*[@id="templ_list0"]/div[7]/div/a""").click()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
import os
from glob import glob

for file in glob("../data/지역_*"):
    os.remove(file)

len(glob("../data/지역_*"))
# Out:
# 0

# %%
import os 

for file in glob("../data/fuel/지역_*"):
    os.remove(file)

len(glob("../data/fuel/지역_*"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
# ----> 3 for file in glob("../data/fuel/지역_*"):
#       4     os.remove(file)
#       6 len(glob("../data/fuel/지역_*"))
#
# NameError: name 'glob' is not defined

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
import time

import os 

for file in glob("../data/fuel3/지역_*"):
    os.remove(file)

len(glob("../data/fuel3/지역_*"))

# for idx, gu_name in tqdm(enumerate(gu_names), total=len(gu_names)):
#     gu = driver.find_element(By.ID, "SIGUNGU_NM0")
#     gu.send_keys(gu_name)
#     # driver.implicitly_wait(3)
#     driver.refresh()

#     save = WebDriverWait(driver, 3).\
#         until(EC.element_to_be_clickable((By.XPATH, """//*[@id="templ_list0"]/div[7]/div/a"""))) 

#     ActionChains(driver).move_to_element(save).perform()
#     save.click()

#     file_count = len(glob("../data/fuel3/지역_*"))
#     while (file_count < idx + 1):
#         time.sleep(0.1)
#         file_count = len(glob("../data/fuel3/지역_*"))

# len(glob("../data/fuel3/지역_*"))    


# for idx, gu_name in tqdm(enumerate(gu_names), total=len(gu_names)):
#     gu = driver.find_element(By.ID, "SIGUNGU_NM0")
#     gu.send_keys(gu_name)
#     driver.refresh()
#     save = WebDriverWait(driver, 3).\
#         until(EC.element_to_be_clickable((By.XPATH, """//*[@id="templ_list0"]/div[7]/div/a""")))
#     ActionChains(driver).move_to_element(save).perform()
#     save.click()
#     file_count = len(glob("../data/fuel3/지역_*"))
#     while (file_count < idx + 1):
#         time.sleep(0.1)
#         file_count = len(glob("../data/fuel3/지역_*"))
# len(glob("../data/fuel3/지역_*"))


# for idx, gu_name in tqdm(enumerate(gu_names), total=len(gu_names)):
#     # 페이지 새로고침
#     driver.refresh()

# # 새로 고침 후 요소가 로드될 때까지 대기
#     gu = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.ID, "SIGUNGU_NM0")))

# # 구 이름 입력
#     gu.send_keys(gu_name)

# # 다운로드 버튼 클릭
#     save = WebDriverWait(driver, 3).until(
#     EC.element_to_be_clickable((By.XPATH, """//*[@id="templ_list0"]/div[7]/div/a"""))
# )
#     ActionChains(driver).move_to_element(save).perform()
#     save.click()

# # 파일이 다운로드될 때까지 대기
#     file_count = len(glob("../data/fuel3/지역_*"))
#     while file_count < idx + 1:
#         time.sleep(0.1)
#         file_count = len(glob("../data/fuel3/지역_*"))

# len(glob("../data/fuel3/지역_*"))
# Out:
# 0

# %%
from glob import glob

file_list = glob("../data/fuel3/지역_*")
print(len(file_list))
file_list
# Out:
# 25
# ['../data/fuel3/지역_위치별(주유소) (20).xls',
#  '../data/fuel3/지역_위치별(주유소) (18).xls',
#  '../data/fuel3/지역_위치별(주유소) (4).xls',
#  '../data/fuel3/지역_위치별(주유소) (15).xls',
#  '../data/fuel3/지역_위치별(주유소) (24).xls',
#  '../data/fuel3/지역_위치별(주유소) (22).xls',
#  '../data/fuel3/지역_위치별(주유소) (1).xls',
#  '../data/fuel3/지역_위치별(주유소) (6).xls',
#  '../data/fuel3/지역_위치별(주유소).xls',
#  '../data/fuel3/지역_위치별(주유소) (2).xls',
#  '../data/fuel3/지역_위치별(주유소) (21).xls',
#  '../data/fuel3/지역_위치별(주유소) (3).xls',
#  '../data/fuel3/지역_위치별(주유소) (19).xls',
#  '../data/fuel3/지역_위치별(주유소) (13).xls',
#  '../data/fuel3/지역_위치별(주유소) (16).xls',
#  '../data/fuel3/지역_위치별(주유소) (12).xls',
#  '../data/fuel3/지역_위치별(주유소) (8).xls',
#  '../data/fuel3/지역_위치별(주유소) (10).xls',
#  '../data/fuel3/지역_위치별(주유소) (23).xls',
#  '../data/fuel3/지역_위치별(주유소) (5).xls',
#  '../data/fuel3/지역_위치별(주유소) (17).xls',
#  '../data/fuel3/지역_위치별(주유소) (11).xls',
#  '../data/fuel3/지역_위치별(주유소) (14).xls',
#  '../data/fuel3/지역_위치별(주유소) (7).xls',
#  '../data/fuel3/지역_위치별(주유소) (9).xls']

# %%
import pandas as pd

data = pd.read_excel(file_list[0], header=2)
data.tail(2)
# Out:
#        지역                 상호                       주소     상표         전화번호  \
# 24  서울특별시  KH에너지㈜직영 KH여의도주유소  서울 영등포구 국회대로 794 (여의도동)  SK에너지  02-761-5101
# 25  서울특별시     SJ오일(주) 여의도주유소           서울 영등포구 은행로 64  GS칼텍스  02-785-8201
#
#    셀프여부 고급휘발유   휘발유    경유  실내등유
# 24    N  2310  2195  2189     -
# 25    N  2410  2255  2195  1750

# %%
data_list = []

for file in file_list:
    data = pd.read_excel(file, header=2)
    data_list.append(data)

oil_data = pd.concat(data_list)
len(oil_data)

oil_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 493 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      493 non-null    object
#  1   상호      493 non-null    object
#  2   주소      493 non-null    object
#  3   상표      493 non-null    object
#  4   전화번호    493 non-null    object
#  5   셀프여부    493 non-null    object
#  6   고급휘발유   493 non-null    object
#  7   휘발유     493 non-null    int64
#  8   경유      493 non-null    int64
#  9   실내등유    493 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 42.4+ KB

# %%
oil_data = pd.DataFrame({"상호": oil_data["상호"],
                         "주소": oil_data["주소"],
                         "가격": oil_data["휘발유"],
                         "셀프": oil_data["셀프여부"],
                         "상표": oil_data["상표"]
})

oil_data.tail()
# Out:
#                      상호                    주소    가격 셀프        상표
# 9   (주)헨지스에너지 구도일주유소 도봉  서울 도봉구 도봉로 706 (방학동)  1649  Y     S-OIL
# 10            삼미북부셀프주유소  서울 도봉구 도봉로 437 (쌍문동)  1649  Y     SK에너지
# 11           구도일주유소 파크빌  서울 도봉구 해등로3길 86 (창동)  1659  Y     S-OIL
# 12                오복주유소         서울 도봉구 방학로 43  1735  Y     S-OIL
# 13    HD현대오일뱅크㈜직영 영신주유소        서울 도봉구 방학로 151  1817  N  HD현대오일뱅크

# %%
oil_data.reset_index(drop=True, inplace=True)
oil_data.tail()
# Out:
#                       상호                    주소    가격 셀프        상표
# 488  (주)헨지스에너지 구도일주유소 도봉  서울 도봉구 도봉로 706 (방학동)  1649  Y     S-OIL
# 489            삼미북부셀프주유소  서울 도봉구 도봉로 437 (쌍문동)  1649  Y     SK에너지
# 490           구도일주유소 파크빌  서울 도봉구 해등로3길 86 (창동)  1659  Y     S-OIL
# 491                오복주유소         서울 도봉구 방학로 43  1735  Y     S-OIL
# 492    HD현대오일뱅크㈜직영 영신주유소        서울 도봉구 방학로 151  1817  N  HD현대오일뱅크

# %%
oil_data["구"] = [address.split()[1] for address in oil_data["주소"]]
oil_data.head()
# Out:
#                상호                      주소    가격 셀프        상표     구
# 0           성락주유소  서울 영등포구 가마산로 414 (신길동)  1635  Y     S-OIL  영등포구
# 1      영등포제일셀프주유소        서울 영등포구 가마산로 379  1635  Y  HD현대오일뱅크  영등포구
# 2  (주)대청에너지 대청주유소  서울 영등포구 가마산로 328 (대림동)  1635  Y     GS칼텍스  영등포구
# 3           도림주유소   서울 영등포구 도림로 343 (도림동)  1645  Y     알뜰주유소  영등포구
# 4        남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1645  Y     SK에너지  영등포구

# %%
oil_data["구"].unique(), len(oil_data["구"].unique())
# Out:
# (array(['영등포구', '양천구', '강서구', '서초구', '중랑구', '종로구', '강남구', '구로구', '강북구',
#         '은평구', '서대문구', '동작구', '도봉구', '광진구', '송파구'], dtype=object),
#  15)

# %%
oil_data["가격"] = oil_data["가격"].astype("float")

# %%
oil_data
# Out:
#                      상호                      주소    가격 셀프        상표     구
# 0                 성락주유소  서울 영등포구 가마산로 414 (신길동)  1635  Y     S-OIL  영등포구
# 1            영등포제일셀프주유소        서울 영등포구 가마산로 379  1635  Y  HD현대오일뱅크  영등포구
# 2        (주)대청에너지 대청주유소  서울 영등포구 가마산로 328 (대림동)  1635  Y     GS칼텍스  영등포구
# 3                 도림주유소   서울 영등포구 도림로 343 (도림동)  1645  Y     알뜰주유소  영등포구
# 4              남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1645  Y     SK에너지  영등포구
# ..                  ...                     ...   ... ..       ...   ...
# 9   (주)헨지스에너지 구도일주유소 도봉    서울 도봉구 도봉로 706 (방학동)  1649  Y     S-OIL   도봉구
# 10            삼미북부셀프주유소    서울 도봉구 도봉로 437 (쌍문동)  1649  Y     SK에너지   도봉구
# 11           구도일주유소 파크빌    서울 도봉구 해등로3길 86 (창동)  1659  Y     S-OIL   도봉구
# 12                오복주유소           서울 도봉구 방학로 43  1735  Y     S-OIL   도봉구
# 13    HD현대오일뱅크㈜직영 영신주유소          서울 도봉구 방학로 151  1817  N  HD현대오일뱅크   도봉구
#
# [493 rows x 6 columns]

# %%
oil_data.reset_index(drop=True, inplace=True)
oil_data.head()
# Out:
#                상호                      주소    가격 셀프        상표     구
# 0           성락주유소  서울 영등포구 가마산로 414 (신길동)  1635  Y     S-OIL  영등포구
# 1      영등포제일셀프주유소        서울 영등포구 가마산로 379  1635  Y  HD현대오일뱅크  영등포구
# 2  (주)대청에너지 대청주유소  서울 영등포구 가마산로 328 (대림동)  1635  Y     GS칼텍스  영등포구
# 3           도림주유소   서울 영등포구 도림로 343 (도림동)  1645  Y     알뜰주유소  영등포구
# 4        남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1645  Y     SK에너지  영등포구

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

oil_data.boxplot(column="가격", by="셀프", figsize=(12,8));

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="셀프", y="가격", data=oil_data, palette="Set1")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=oil_data, palette="Set3")
plt.grid(True)
plt.show()

# %%
import json
import folium
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

oil_data.sort_values(by="가격", ascending=False).head(10)
# Out:
#                       상호                     주소    가격 셀프        상표    구
# 160  (주)제이제이네트웍스 제이제이주유소         서울 강남구 언주로 716  2498  N  HD현대오일뱅크  강남구
# 206  (주)제이제이네트웍스 제이제이주유소         서울 강남구 언주로 716  2498  N  HD현대오일뱅크  강남구
# 205         (주)소모 쎈트럴주유소         서울 강남구 삼성로 335  2448  N     GS칼텍스  강남구
# 159         (주)소모 쎈트럴주유소         서울 강남구 삼성로 335  2448  N     GS칼텍스  강남구
# 204              SK논현주유소   서울 강남구 논현로 747 (논현동)  2395  N     SK에너지  강남구
# 158              SK논현주유소   서울 강남구 논현로 747 (논현동)  2395  N     SK에너지  강남구
# 132       (주)대양씨앤씨 사직주유소          서울 종로구 사직로 65  2365  N     GS칼텍스  종로구
# 380       (주)대양씨앤씨 사직주유소          서울 종로구 사직로 65  2365  N     GS칼텍스  종로구
# 178                구로주유소  서울 구로구 구로동로 137 (구로동)  2290  N     GS칼텍스  구로구
# 358                구로주유소  서울 구로구 구로동로 137 (구로동)  2290  N     GS칼텍스  구로구

# %%
oil_data.sort_values(by="가격", ascending=True).head(10)
# Out:
#                    상호                      주소    가격 셀프        상표    구
# 83   ㈜에이치앤디이 만남의광장주유소    서울 서초구 양재대로12길 73-71  1594  Y    알뜰(ex)  서초구
# 431  ㈜에이치앤디이 만남의광장주유소    서울 서초구 양재대로12길 73-71  1594  Y    알뜰(ex)  서초구
# 302  ㈜에이치앤디이 만남의광장주유소    서울 서초구 양재대로12길 73-71  1594  Y    알뜰(ex)  서초구
# 218             불광주유소          서울 은평구 연서로 314  1608  Y  HD현대오일뱅크  은평구
# 219          박석고개2주유소          서울 은평구 통일로 924  1608  Y     SK에너지  은평구
# 216           박석고개주유소    서울 은평구 통일로 945 (갈현동)  1608  Y     SK에너지  은평구
# 217  (주)디오티디 은평유니콘주유소         서울 은평구 통일로 1151  1608  N  HD현대오일뱅크  은평구
# 381         서울중앙고속주유소    서울 광진구 동일로 345 (중곡동)  1615  Y     SK에너지  광진구
# 26       ㈜자연에너지 남부주유소  서울 양천구 남부순환로 553 (신월동)  1616  Y  HD현대오일뱅크  양천구
# 220       ㈜한화미 구파발주유소         서울 은평구 통일로 1031  1618  Y     S-OIL  은평구

# %%
import numpy as np

gu_data = pd.pivot_table(data=oil_data, index="구", values="가격", aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1906.857143
# 강북구  1652.555556
# 강서구  1691.575758
# 광진구  1683.692308
# 구로구  1723.611111

# %%
import folium

geo_path = "../data/02. skorea_municipalities_geo_simple.json"
get_str = json.load(open(geo_path, encoding="utf-8"))

map = folium.Map(location=(37.5502, 126.982), zoom_start=10.5, tiles="OpenStreetMap")
setting = folium.Choropleth(geo_data=get_str,
                            data=gu_data,
                            columns=[gu_data.index, "가격"],
                            key_on="feature.id",
                            fill_color="PuRd")

setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8617a28ed73d44af645f628bb808b1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8617a28ed73d44af645f628bb808b1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8617a28ed73d44af645f628bb808b1b = L.map(
#                 &quot;map_b8617a28ed73d44af645f628bb808b1b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c431b708dc2b68f8cf4be432d1848b15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c431b708dc2b68f8cf4be432d1848b15.addTo(map_b8617a28ed73d44af645f628bb808b1b);
#
#
#             var choropleth_a2201648741cac50ed6f2c0d8d3a9840 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_876f24e9068b3353946d5af404cb38b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_876f24e9068b3353946d5af404cb38b3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_876f24e9068b3353946d5af404cb38b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_876f24e9068b3353946d5af404cb38b3_onEachFeature,
#
#                 style: geo_json_876f24e9068b3353946d5af404cb38b3_styler,
#             ...{
# }
#         });
#
#         function geo_json_876f24e9068b3353946d5af404cb38b3_add (data) {
#             geo_json_876f24e9068b3353946d5af404cb38b3
#                 .addData(data);
#         }
#             geo_json_876f24e9068b3353946d5af404cb38b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080
