# %%
import os
import sys
import urllib.request
client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2017-04-30\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"한글\",\"keywords\":[\"한글\",\"korean\"]},{\"groupName\":\"영어\",\"keywords\":[\"영어\",\"english\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

print(response.read().decode('utf-8'))
# Out:
# {"startDate":"2017-01-01","endDate":"2017-04-30","timeUnit":"month","results":[{"title":"한글","keywords":["한글","korean"],"data":[{"period":"2017-01-01","ratio":47.00101},{"period":"2017-02-01","ratio":53.23619},{"period":"2017-03-01","ratio":100},{"period":"2017-04-01","ratio":85.327}]},{"title":"영어","keywords":["영어","english"],"data":[{"period":"2017-01-01","ratio":40.0881},{"period":"2017-02-01","ratio":36.69942},{"period":"2017-03-01","ratio":52.11792},{"period":"2017-04-01","ratio":44.4595}]}]}

# %%
# 블로그


import os
import sys
import urllib.request

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)


print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Tue, 24 Jun 2025 14:20:19 +0900",
# 	"total":535882,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"강남 AI특강, <b>파이썬<\/b>으로 시작하는 실전 수업",
# 			"link":"https:\/\/blog.naver.com\/purplepeach81\/223902982714",
# 			"description":"결국 <b>파이썬<\/b>으로 수렴되더라고요. 문법도 어렵지 않고, 무엇보다 인공지능이나 빅데이터 같은 분야에서 거의 필수처럼 쓰인다고 하니까요. 이 강의의 커리큘럼을 살펴봤을 때 <b>파이썬<\/b> 중심으로 구성되어 있다는... ",
# 			"bloggername":"퍼플피치",
# 			"bloggerlink":"blog.naver.com\/purplepeach81",
# 			"postdate":"20250618"
# 		},
# 		{
# 			"title":"대전<b>파이썬<\/b>학원 단계별 코딩 실무 학습 과정",
# 			"link":"https:\/\/blog.naver.com\/she_op\/223881011131",
# 			"description":"그래서 대전<b>파이썬<\/b>학원을 알아보기로 했죠. 아무 데서나 할 순 없고 커리큘럼을 단계별 실무 위주로... 기초 코딩: 프로그래밍 언어 이 과정은 대전<b>파이썬<\/b>학원에 처음 오는 입문자들이 프로그래밍 언어를... ",
# 			"bloggername":"오롯이 여행, 마음먹기 나름 :)",
# 			"bloggerlink":"blog.naver.com\/she_op",
# 			"postdate":"20250528"
# 		},
# 		{
# 			"title":"빅데이터분석기사 <b>파이썬<\/b> 시험 공부방법 합격후기",
# 			"link":"https:\/\/blog.naver.com\/blackhole_chinese\/223900117182",
# 			"description":"빅데이터분석기사 <b>파이썬<\/b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬<\/b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬<\/b> 시험 공부방법 합격후기 빅데이터분석기사 취득자의 후기를 소개합니다.... ",
# 			"bloggername":"묘한 교육 연구소",
# 			"bloggerlink":"blog.naver.com\/blackhole_chinese",
# 			"postdate":"20250615"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>전문가 자격증 종류 및 효율적인 취득방법",
# 			"link":"https:\/\/blog.naver.com\/mellybird\/223842981098",
# 			"description":"<b>파이썬<\/b>전문가 자격증 종류 및 효율적인 취득방법 <b>파이썬<\/b>은 요즘 다양한 분야에서 널리 사용되는 프로그래밍 언어로, 데이터 분석, 웹 개발, 인공지능 등에서 중요한 역할을 하고 있습니다. 저는 원래... ",
# 			"bloggername":"멜잉로그 : 현직 국내파 영어강사 블로그",
# 			"bloggerlink":"blog.naver.com\/mellybird",
# 			"postdate":"20250422"
# 		},
# 		{
# 			"title":"대구<b>파이썬<\/b>학원 실전 기술 익힌 곳",
# 			"link":"https:\/\/blog.naver.com\/xshinerx\/223787876858",
# 			"description":"그때 힘이 되어 준 대구<b>파이썬<\/b>학원에 대한 글을 써보려 해요! IT 위주로 학습하는 곳 단순히 구직에... 이 대구<b>파이썬<\/b>학원은 전직, 현직 강사들이 비전공자도 따라갈 수 있을 정도로 눈높이 교육을 진행해 준다고... ",
# 			"bloggername":"▶ 제이의 맛있는 세상 ◀",
# 			"bloggerlink":"blog.naver.com\/xshinerx",
# 			"postdate":"20250308"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>전문가 자격증 학습방법 취득후기",
# 			"link":"https:\/\/blog.naver.com\/bbobbny\/223842932148",
# 			"description":"<b>파이썬<\/b>전문가 자격증 학습방법 취득후기 요즘 IT 분야에 대한 관심이 점점 더 높아지며 앞으로 어떤... 그러던 중 남들에게 제가 알고 있는 기술을 알려주고 싶은 마음에 <b>파이썬<\/b>전문가 자격증에 도전했고 나만의... ",
# 			"bloggername":"ALICEMADE-앨리스가 만들어가는 세상",
# 			"bloggerlink":"blog.naver.com\/bbobbny",
# 			"postdate":"20250422"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>자격증 종류 취업 분야 및 공부 후기",
# 			"link":"https:\/\/blog.naver.com\/kang6902\/223863482199",
# 			"description":"<b>파이썬<\/b>자격증 종류 취업 분야 및 공부 후기 공부하신 분의 후기를 바탕으로 작성되었음을... 결심하고 처음으로 도전한 것은 <b>파이썬<\/b>자격증이었어요. 입문용 언어라 가장 저에게 적합했는데요. 같은... ",
# 			"bloggername":"세 아이와 함께 성장하는 곳",
# 			"bloggerlink":"blog.naver.com\/kang6902",
# 			"postdate":"20250512"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>전문가 자격증 종류 체계적인 취득방법 및 학습과정",
# 			"link":"https:\/\/blog.naver.com\/career4ukr\/223842923010",
# 			"description":"<b>파이썬<\/b>전문가 자격증 종류 체계적인 취득방법 및 학습과정 요즘은 취업하려면 코딩은 필수인 거... 오늘 <b>파이썬<\/b>전문가 자격증 종류 체계적인 취득방법 및 학습과정을 가져와 보았습니다! <b>파이썬<\/b> 자격증 종류... ",
# 			"bloggername":"하영목(출간작가)의 블로그",
# 			"bloggerlink":"blog.naver.com\/career4ukr",
# 			"postdate":"20250422"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원, 전공 대비 여름방학 특강",
# 			"link":"https:\/\/blog.naver.com\/smgong00\/223903445166",
# 			"description":"그런데 요즘은 '<b>파이썬<\/b>'이 대세라는데요 <b>파이썬<\/b>은 왜 전공자에게 필수 언어가 되었을까? 프로그래밍 언어는 수업이 많지만, 최근 몇 년 사이 전공자들이 입을 모아 &quot;<b>파이썬<\/b>은 무조건 해둬야 해&quot;라고 말하는... ",
# 			"bloggername":"지혜를 여는 부엉이상점",
# 			"bloggerlink":"blog.naver.com\/smgong00",
# 			"postdate":"20250618"
# 		},
# 		{
# 			"title":"AI 인공지능 프로젝트 <b>파이썬<\/b> 프로젝트 입문자를 위한 책 추천",
# 			"link":"https:\/\/kwangho.tistory.com\/531581",
# 			"description":"AI 인공지능 프로젝트 <b>파이썬<\/b> 프로젝트 입문자를 위한 책 추천 AI와 프로그래밍이 더 이상... <b>파이썬<\/b>으로 어떻게 AI 개발 프로젝트를 시작할지 막막하신 분을 위한 입문 개발서적을 가져왔습니다.... ",
# 			"bloggername":"엔돌슨의 IT이야기",
# 			"bloggerlink":"https:\/\/kwangho.tistory.com\/",
# 			"postdate":"20250613"
# 		}
# 	]
# }

# %%
#카페

import os
import sys
import urllib.request

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)


print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Tue, 24 Jun 2025 14:20:19 +0900",
# 	"total":217064,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 고수분 궁금한게 있습니다",
# 			"link":"http:\/\/cafe.naver.com\/consumerizm\/2349482",
# 			"description":"--------------------------------------------------------------------------- <b>파이썬<\/b> 공부한지 3시간 정도 되었습니다.... 소괄호 중괄호 사용하는 것도 구분이 있는지 단순 암기인지 궁금합니다. <b>파이썬<\/b> 고수가 되기 위해... 감사합니다",
# 			"cafename":"K R R R",
# 			"cafeurl":"https:\/\/cafe.naver.com\/consumerizm"
# 		},
# 		{
# 			"title":"코딩 자바 <b>파이썬<\/b> 차이",
# 			"link":"http:\/\/cafe.naver.com\/kkaebangjeong\/211315",
# 			"description":"국비 지원 받아서 코딩 배우고 싶은데 커리큘럼을 보면 자바 기반이나 <b>파이썬<\/b> 기반 이렇게 두가지 있던데 차이가 있나요? 초보이다 보니 잘 몰라서요..! 자바는 백엔드 개발에 쓰이고 <b>파이썬<\/b>은 데이터분석, ai분야쪽에서... ",
# 			"cafename":"국비모★국민내일배움카드,국비교육,국...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/kkaebangjeong"
# 		},
# 		{
# 			"title":"점프 투 <b>파이썬<\/b>",
# 			"link":"http:\/\/cafe.naver.com\/kongdae\/205122",
# 			"description":"- 책 제목 (글의 제목에도 반드시 책제목을 적어주세요) 점프 투 <b>파이썬<\/b> - 추천하는 대상 (예: 뇌공학에 관심있는 중고등학생) <b>파이썬<\/b>을 공부해보고 싶은 초고 중 고 학생 - 추천하는 이유 (100자 이상 작성 권장) <b>파이썬<\/b>이란... ",
# 			"cafename":"[이공계의 별★서울대,KAIST,POSTECH,...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/kongdae"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 공부",
# 			"link":"http:\/\/cafe.naver.com\/tmxk9999\/57661",
# 			"description":"2학기때 전공으로 <b>파이썬<\/b> 있어서 이걸로 이번 방학때 독학해볼려고 하는데 이 책 어떤가요?",
# 			"cafename":"괴공카",
# 			"cafeurl":"https:\/\/cafe.naver.com\/tmxk9999"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 자료구조와 알고리즘",
# 			"link":"http:\/\/cafe.naver.com\/kongdae\/205337",
# 			"description":"- 책 제목 (글의 제목에도 반드시 책제목을 적어주세요) <b>파이썬<\/b> 자료구조와 알고리즘 - 추천하는 대상... 이 책은 <b>파이썬<\/b>을 통해 자료구조와 알고리즘의 기본 개념을 익힐 수 있도록 구성되어 있어, 컴퓨터공학적 사고의... ",
# 			"cafename":"[이공계의 별★서울대,KAIST,POSTECH,...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/kongdae"
# 		},
# 		{
# 			"title":"부산대 통계학과 <b>파이썬<\/b>",
# 			"link":"http:\/\/cafe.naver.com\/suhui\/28870752",
# 			"description":"부산대 통계학과 <b>파이썬<\/b>은 언제배우나요? 방학동안 학원을 보낼까 싶어서요.. 학과 과정에는 2-1선택이라고 되어있어서 겨울방학때 공부하면 될까요?",
# 			"cafename":"수만휘-수능날만점시험지를휘날리자★...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/suhui"
# 		},
# 		{
# 			"title":"r\/<b>파이썬<\/b>",
# 			"link":"http:\/\/cafe.naver.com\/sqlpd\/92238",
# 			"description":"여기서 문제별로 R\/<b>파이썬<\/b>을 선택해서 풀 수 있다는 글을 봤는데 진짠가요...? 시험 환경이 어떻게 되었길래 두 개를 같이 쓸 수 있나요?! 위에 따로 선택하는 게 있는 건가요 지금 시험 환경 링크가 안 들어먹어서 궁금해요...",
# 			"cafename":"데이터 전문가 포럼 (빅데이터분석기사...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/sqlpd"
# 		},
# 		{
# 			"title":"BLE 블루투스 <b>파이썬<\/b> 코드 질문있습니다.",
# 			"link":"http:\/\/cafe.naver.com\/carroty\/402698",
# 			"description":"아두이노 + BLE 모듈 - <b>파이썬<\/b> (Window) 데이터 송수신을 하려고 합니다. 아래와... 아두이노에서 데이터를 보낼때 <b>파이썬<\/b>에서 받았다고는 뜨는데 0xff 로만 값이... ",
# 			"cafename":"당근이의 AVR 갖구 놀기",
# 			"cafeurl":"https:\/\/cafe.naver.com\/carroty"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 공부 순서, 어떻게 잡는 게 맞을까요?",
# 			"link":"http:\/\/cafe.naver.com\/cafec\/403067",
# 			"description":"안녕하세요, 최근에 국비지원 과정 등록하고 <b>파이썬<\/b>을 본격적으로 배우게 된 비전공자입니다. <b>파이썬<\/b> 기초문법은 유튜브랑 책 보면서 어느 정도 익히긴 했는데, 어디서부터 뭘 어떻게 이어나가야 할지 좀 막막하네요.... ",
# 			"cafename":"IT 스토어 [ C언어 코딩 AI 게임 개발...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/cafec"
# 		},
# 		{
# 			"title":"게인워드 5070 <b>파이썬<\/b> 구매후기",
# 			"link":"http:\/\/cafe.naver.com\/fx8300\/1109074",
# 			"description":"5070게인워드 <b>파이썬<\/b>은 소음이 없을정도로 조용하네요 그리고 성능도 준수한거같습니다 ㅎㅎ 그리고 벤큐만 쓰다가 qhd모니터를 쓰고싶어서 글카를 알아보다가 게인워드 <b>파이썬<\/b> 5070을 돌아갈까 의심도 해봤지만... ",
# 			"cafename":"AMD 비쉐라 라이젠 컴퓨터 사용자 모임",
# 			"cafeurl":"https:\/\/cafe.naver.com\/fx8300"
# 		}
# 	]
# }

# %%
# 네이버책

import os
import sys
import urllib.request

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
encText = urllib.parse.quote("부등가교환")
url = "https://openapi.naver.com/v1/search/book?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)


print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Tue, 24 Jun 2025 14:20:19 +0900",
# 	"total":1,
# 	"start":1,
# 	"display":1,
# 	"items":[
# 		{
# 			"title":"국제분업, 구조화된 부등가교환 (한국경제와 미,일 국제분업)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32497546756",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3249754\/32497546756.20220527044104.jpg",
# 			"author":"정양택",
# 			"discount":"0",
# 			"publisher":"헬리콥터",
# 			"pubdate":"20201028",
# 			"isbn":"9791197118371",
# 			"description":"이 책은 외환위기 이전과 이후의 한국경제를 국제 분업의 유지. 강화라는 동일성의 측면에서 분석하고 있습니다. \n2000년대부터 확산된 힘들고, 더럽고, 위험한 노동에 대한 외국인 노동자 외주화 혹은 비정규직 노동자 외주화는 \n1970-1980년대 개발독재하의 저임금수출노동의 재편성에 지나지 않는다고 보는 관점입니다. \n또한 주식투자 열풍이나 부동산투기 광풍은 현대판 ‘잘살아보세’ 운동에 불과하다는 시각입니다.\n그렇더라도 외환위기 이전과 이후의 차이점은 전혀 새로운 지점에서 점점 분명해 지고 있습니다. \n이 책은 ‘전혀 새로운 지점’을 설명하고 있지 않지만, 그것에 대한 시야를 넓히는 입문서가 될 것입니다. \n또한 이 책은 외환위기 이후 한국경제에 대한 정치경제적 시각의 기초를 제공할 것입니다. \n‘전혀 새로운 지점’에 대한 저자의 다음 저작을 기다려주시면 감사하겠습니다."
# 		}
# 	]
# }

# %%
# 쇼핑

import os
import sys
import urllib.request

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)


print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Tue, 24 Jun 2025 14:20:19 +0900",
# 	"total":105434,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"드래곤디퓨전 산타크로체 스몰 8893 드래곤백 탄 블랙 화이트 라탄가방 토트백 여름 휴가",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/10308403572",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8785290\/87852907678.3.jpg",
# 			"lprice":"586000",
# 			"hprice":"",
# 			"mallName":"르까느",
# 			"productId":"87852907678",
# 			"productType":"2",
# 			"brand":"드래곤디퓨전",
# 			"maker":"드래곤디퓨전",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"드래곤디퓨전 빅 버켓 8930 드래곤백 탄 라탄가방 숄더 토트백 여름 휴가",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/10322126863",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8786663\/87866630989.1.jpg",
# 			"lprice":"369000",
# 			"hprice":"",
# 			"mallName":"르까느",
# 			"productId":"87866630989",
# 			"productType":"2",
# 			"brand":"드래곤디퓨전",
# 			"maker":"드래곤디퓨전",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"닥스 <b>파이톤<\/b> 배색 토트백 S DCBA4F082",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/52480193450",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5248019\/52480193450.20250114102233.jpg",
# 			"lprice":"390220",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"52480193450",
# 			"productType":"1",
# 			"brand":"닥스",
# 			"maker":"LF",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"슈펜 패딩 플랩 라운드 미니백 HPABGD4V06",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/52818653989",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5281865\/52818653989.20250205123254.jpg",
# 			"lprice":"18470",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"52818653989",
# 			"productType":"1",
# 			"brand":"슈펜",
# 			"maker":"이랜드",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"[엘러브] 샤넬 서프백 다크그린 금장 <b>파이톤<\/b> 5ET0191",
# 			"link":"https:\/\/www.shinsegaetvshopping.com\/display\/detail\/77689809?inMediaCode=EC12&ckwhere=naverep",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5296257\/52962575357.jpg",
# 			"lprice":"3245700",
# 			"hprice":"",
# 			"mallName":"신세계라이브쇼핑",
# 			"productId":"52962575357",
# 			"productType":"2",
# 			"brand":"샤넬",
# 			"maker":"",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"롱샴 longchamp 르 플리아쥬 neo 데일리 탑 핸들 미니 백 L1500598",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/9911076306",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8745557\/87455578579.2.jpg",
# 			"lprice":"119600",
# 			"hprice":"",
# 			"mallName":"슈퍼직구레이블",
# 			"productId":"87455578579",
# 			"productType":"2",
# 			"brand":"롱샴",
# 			"maker":"",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"[국내제작] 헤르몬 프리미엄 크로커 소가죽토트백 플룸 스퀘어 여성숄더백 와니 크로스백 140",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/11134677464",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8867918\/88679187786.4.jpg",
# 			"lprice":"104000",
# 			"hprice":"",
# 			"mallName":"헤르몬",
# 			"productId":"88679187786",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"닥스 로고 토트백 M DCBA4F083BK",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/52468308327",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5246830\/52468308327.20250113170638.jpg",
# 			"lprice":"421870",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"52468308327",
# 			"productType":"1",
# 			"brand":"닥스",
# 			"maker":"LF",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"망고 I NASTY 87005746",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/55381714759",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5538171\/55381714759.20250619161221.jpg",
# 			"lprice":"37050",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"55381714759",
# 			"productType":"1",
# 			"brand":"망고",
# 			"maker":"망고",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>파이톤<\/b> 뱀피 보스턴백 뱀가방",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/4643120905",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8218764\/82187641380.1.jpg",
# 			"lprice":"550000",
# 			"hprice":"",
# 			"mallName":"로브파이톤",
# 			"productId":"82187641380",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션잡화",
# 			"category2":"여성가방",
# 			"category3":"토트백",
# 			"category4":""
# 		}
# 	]
# }

# %%
# 백과사전

import os
import sys
import urllib.request

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)


print(response.read().decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Tue, 24 Jun 2025 14:20:19 +0900",
# 	"total":51,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# 			"description":"최근 몇 년 사이 프로그래밍을 비전공자들에게 알려주는 문화가 전 세계적으로 확산되고 있다. 하버드나 예일대 같은 해외 대학 뿐만 아니라 카이스트, 국민대, 성균관대 등 국내 대학에서도 프로 ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_5\/20170316151437004_YY6SI76G0.PNG\/image_2.PNG?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# 			"description":"컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어. <b>파이썬<\/b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4751_000_3\/20170710213206672_OPHLG2VOW.jpg\/992_170575_10034.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3533295&cid=40942&categoryId=32838",
# 			"description":"오픈소스 고급 프로그래밍 언어 중 하나이다. C언어를 기반으로 한 오픈소스 고급 프로그래밍 언어로, 1991년 귀도 반 로섬(Guido van Rossum)에 의해 설계 및 개발되었다. <b>파이썬<\/b>이라는 이름은 <b>파이썬<\/b>을 ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"장고",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=4367087&cid=59088&categoryId=59096",
# 			"description":"장고는 <b>파이썬<\/b> 기반 웹 애플리케이션 프레임워크다. 좀 더 쉽게 웹 개발을 할 수 있게 돕는 오픈소스 기술이다. 장고는 개발 과정을 단축시켜주고, 다양한 추가 기능을 포함하고 있으며 보 ",
# 			"thumbnail":"https:\/\/post-phinf.pstatic.net\/MjAxNzEyMTVfMTM1\/MDAxNTEzMzI3NDI4MjIz.nZhrYOO1nwD5YToYQRQoI8UH4MdHD8_SOjO2Uu_A45Ug.Is-NiXSP4wOgQDVNW_8j6QrMId6m1vlOohGSK1pEHa0g.JPEG\/3053411300_9146d6f2aa_o.jpg?type=m4500_4500_fst"
# 		},
# 		{
# 			"title":"젯브레인",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3580711&cid=59088&categoryId=59096",
# 			"description":"전 세계 개발자들이 즐겨 사용하는 통합 개발 환경(Integrated Development Environment, IDE)은 어떤 것이 있을까? 많은 개발자들이 마이크로소프트(MS)의 ‘비주얼 스튜디오’나 이클립스 재단의 ‘이클립스 ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_5\/20170316151421387_4PN89KS8G.jpg\/thumbs_13.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"초소형PC",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3576488&cid=59088&categoryId=59096",
# 			"description":"손바닥 위에 올려놓은 초소형PC. 라즈베리 파이(초기형). PC를 한 대 마련하는 데 어느 정도 비용이 들까. 요즘은 싸다. 20~30만원 선에서 아무리 비싸 봐야 100만원대면 충분하다. 하지만 저렴한 가격 ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_5\/20170316150353631_3PU5DF9JG.jpg\/%25BD%25E6%25B3%25.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"루비 (프로그래밍 언어)",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3581025&cid=59088&categoryId=59096",
# 			"description":"우리가 쓰는 많은 프로그래밍 언어는 북미나 유럽권에서 나온 경우가 많다. C언어는 미국, 자바(Java)는 캐나다, <b>파이썬<\/b>(Python)은 네덜란드, 스칼라(Scala)는 스위스에서 나오는 식이다. 이러한 환경에 ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_5\/20170316151510825_EQII5165B.png\/som_4.png?type=m160_160"
# 		},
# 		{
# 			"title":"사이킷런",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6735856&cid=40942&categoryId=32841",
# 			"description":"<b>파이썬<\/b>의 대표적인 오픈 소스 머신 러닝 라이브러리. 사이킷런은 머신 러닝과 데이터 과학에서 활용하는 대표적인 <b>파이썬<\/b> 오픈소스 라이브러리로, 2010년에 첫 번째 공개 버전이 출시되었다. 사이 ",
# 			"thumbnail":""
# 		},
# 		{
# 			"title":"Perplexity",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=6653705&cid=69974&categoryId=69974",
# 			"description":"Perplexity(복잡도)란 언어 모델의 성능을 측정하는 엔트로피(Entropy) 값을 2를 밑으로 하는 지수 함수로 증폭시켜 계산하는 성능 측도이다. 언어 모델링 과정이나 음성 인식에서 엔트로피를 계산할  ",
# 			"thumbnail":"https:\/\/post-phinf.pstatic.net\/MjAyMjA4MjhfNDgg\/MDAxNjYxNjkyMTczMjI3.2IEVYNlzKicXI-yYu3-JtNBl7gRGusb-i2UPfFozT_8g.uIhO9ts858Cr4VooW7qsTgRI9wtLI2mrwFpcIPxBIM8g.GIF\/%EB%B3%B5%EC%9E%A1%EB%8F%84.gif?type=m4500_4500_fst"
# 		},
# 		{
# 			"title":"Raonbit",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3386326&cid=58370&categoryId=58370",
# 			"description":"[ 1. Raonbit 정의] Raonbit는 Apache Spark 기반의 대용량 실시간 데이터와 배치 데이터를 다양한 분석 도구를 이용하여 쉽고 빠르게 분석할 수 있는 고성능의 빅데이터 분석 플랫폼이다.Raonbit는 BDAS(Berkeley ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4412_000_1\/20160427155320451_4450MPNGS.jpg\/s_sm2_25_i1.jpg?type=m160_160"
# 		}
# 	]
# }

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

gen_search_url('shop', 'TEST', 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %%
import json
import datetime

client_id = "jg__dIEQSdLHVISUZTDL"
client_secret = "ANSxvCd2vn"

def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

gen_search_url('shop', 'TEST', 10, 3)


def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)

    print ("[%s] Url Request Success" % datetime.datetime.now())

    return json.loads(response.read().decode('utf-8'))

url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_onpage(url)

one_result
# Out:
# [2025-06-24 14:22:17.848411] Url Request Success
# {'lastBuildDate': 'Tue, 24 Jun 2025 14:22:17 +0900',
#  'total': 31689,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '[<b>몰스킨</b>] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)',
#    'link': 'http://www.moleskine.co.kr/index.html?branduid=2557327&ref=naver_open',
#    'image': 'https://shopping-phinf.pstatic.net/main_5006626/50066265686.jpg',
#    'lprice': '16200',
#    'hprice': '',
#    'mallName': '몰스킨공식온라인스토어',
#    'productId': '50066265686',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식 노트 소프트커버 포켓 블랙',
#    'link': 'https://smartstore.naver.com/main/products/712789629',
#    'image': 'https://shopping-phinf.pstatic.net/main_1130910/11309100678.3.jpg',
#    'lprice': '30000',
#    'hprice': '',
#    'mallName': '몰스킨스토어',
#    'productId': '11309100678',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '<b>몰스킨</b> 클래식노트 하드커버',
#    'link': 'https://search.shopping.naver.com/catalog/46221773618',
#    'image': 'https://shopping-phinf.pstatic.net/main_4622177/46221773618.20240306165408.jpg',
#    'lprice': '32000',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '46221773618',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '<b>몰스킨</b> 2026 위클리 18개월 다이어리 하드커버 P',
#    'link': 'https://smartstore.naver.com/main/products/11810940511',
#    'image': 'https://shopping-phinf.pstatic.net/main_8935545/89355451098.jpg',
#    'lprice': '35000',
#    'hprice': '',
#    'mallName': '몰스킨스토어',
#    'productId': '89355451098',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 한정판 해리포터 아씨오 라지 데일리 다이어리',
#    'link': 'https://search.shopping.naver.com/catalog/51363137892',
#    'image': 'https://shopping-phinf.pstatic.net/main_5136313/51363137892.20250609032529.jpg',
#    'lprice': '24500',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '51363137892',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'}]}

# %%
one_result['items'][0]['title']
one_result['items'][0]['lprice']
one_result['items'][0]['mallName']
# Out:
# '몰스킨공식온라인스토어'

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]

    result_pd = pd.DataFrame({'title': title, 'lprice': lprice,
                              'hprice': hprice, 'link' : link,
                              'mall' : mall_name},
                              columns=['title', 'lprice', 'hprice', 'link', 'mall'])
    
    return result_pd

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")

    return input_str

url = gen_search_url('shop', '몰스킨', 1, 5)
json_result = get_result_onpage(url)
pd_result = get_fields(json_result)

pd_result
# Out:
# [2025-06-24 14:51:00.587219] Url Request Success
#                                          title lprice hprice  \
# 0  [몰스킨] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)  16200
# 1                       몰스킨 클래식 노트 소프트커버 포켓 블랙  30000
# 2                               몰스킨 클래식노트 하드커버  32000
# 3                몰스킨 2026 위클리 18개월 다이어리 하드커버 P  35000
# 4                 몰스킨 한정판 해리포터 아씨오 라지 데일리 다이어리  24500
#
#                                                 link         mall
# 0  http://www.moleskine.co.kr/index.html?branduid...  몰스킨공식온라인스토어
# 1  https://smartstore.naver.com/main/products/712...       몰스킨스토어
# 2  https://search.shopping.naver.com/catalog/4622...          네이버
# 3  https://smartstore.naver.com/main/products/118...       몰스킨스토어
# 4  https://search.shopping.naver.com/catalog/5136...          네이버

# %%
for n in range(1,1000,100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = []

for n in range(1,1000,100):
    url = gen_search_url('shop', '"몰스킨"', n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)

    result_mol.append(pd_result)

result_mol = pd.concat(result_mol)
# Out:
# [2025-06-24 15:09:38.902394] Url Request Success
# [2025-06-24 15:09:39.136545] Url Request Success
# [2025-06-24 15:09:39.234688] Url Request Success
# [2025-06-24 15:09:39.481035] Url Request Success
# [2025-06-24 15:09:39.696347] Url Request Success
# [2025-06-24 15:09:39.786348] Url Request Success
# [2025-06-24 15:09:40.019230] Url Request Success
# [2025-06-24 15:09:40.115831] Url Request Success
# [2025-06-24 15:09:40.232700] Url Request Success
# [2025-06-24 15:09:40.467808] Url Request Success

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.head()
# Out:
#                                          title lprice hprice  \
# 0                       몰스킨 클래식 노트 소프트커버 포켓 블랙  30000
# 1  [몰스킨] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)  16200
# 2                               몰스킨 클래식노트 하드커버  32000
# 3                     몰스킨 까이에 포켓 블랙 (룰드, 스퀘어드)  17000
# 4              [무료배송] 로이텀 노트 하드커버 A5 2024 신규컬러  31680
#
#                                                 link         mall
# 0  https://smartstore.naver.com/main/products/712...       몰스킨스토어
# 1  http://www.moleskine.co.kr/index.html?branduid...  몰스킨공식온라인스토어
# 2  https://search.shopping.naver.com/catalog/4622...          네이버
# 3  https://smartstore.naver.com/main/products/209...       몰스킨스토어
# 4  https://smartstore.naver.com/main/products/955...       몰스킨스토어

# %%
result_mol['lprice'] = result_mol['lprice'].astype('float')
# result_mol['hprice'] = result_mol['hprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %%
writer = pd.ExcelWriter('./molskin_diary_in_naver_shop.xlsx', engine='xlsxwriter')
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4)
worksheet.set_column('B:B', 65)
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)
worksheet.set_column('F:F', 15)

worksheet.conditional_format('C2:C1001', {'type':'3_color_scale'})

writer.close()

df = pd.read_excel("molskin_diary_in_naver_shop.xlsx")
df.head()
# Out:
#    Unnamed: 0                                        title  lprice  hprice  \
# 0           0                       몰스킨 클래식 노트 소프트커버 포켓 블랙   30000     NaN
# 1           1  [몰스킨] 2025년 클래식 다이어리 (12개월) (데일리, 위클리, 먼슬리)   16200     NaN
# 2           2                               몰스킨 클래식노트 하드커버   32000     NaN
# 3           3                     몰스킨 까이에 포켓 블랙 (룰드, 스퀘어드)   17000     NaN
# 4           4              [무료배송] 로이텀 노트 하드커버 A5 2024 신규컬러   31680     NaN
#
#                                                 link         mall
# 0  https://smartstore.naver.com/main/products/712...       몰스킨스토어
# 1  http://www.moleskine.co.kr/index.html?branduid...  몰스킨공식온라인스토어
# 2  https://search.shopping.naver.com/catalog/4622...          네이버
# 3  https://smartstore.naver.com/main/products/209...       몰스킨스토어
# 4  https://smartstore.naver.com/main/products/955...       몰스킨스토어
